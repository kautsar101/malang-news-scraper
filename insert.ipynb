# %%
from supabase import create_client
from dotenv import load_dotenv
import os

load_dotenv()

supabase = create_client(
    os.getenv("SUPABASE_URL"),
    os.getenv("SUPABASE_KEY")
)
print("connected")
# Out:
# connected

# %%
print(os.getenv("SUPABASE_URL"))
print(os.getenv("SUPABASE_KEY")[:20])
# Out:
# https://flrzdzdyhorbiymqmpyn.supabase.co
# sb_secret_8JDga8pEMX

# %%
from supabase import create_client
from dotenv import load_dotenv
import os

load_dotenv()

supabase = create_client(
    os.getenv("SUPABASE_URL"),
    os.getenv("SUPABASE_KEY")
)

data = {
    "title": "Test Article",
    "author": "Kautsar",
    "published_date": "2026-06-18",
    "content": "Ini test insert dari Python",
    "url": "https://test.com",
    "source": "test"
}

result = (
    supabase
    .table("news_articles")
    .insert(data)
    .execute()
)

print(result)
# Out:
# data=[{'id': 1, 'source': 'test', 'title': 'Test Article', 'url': 'https://test.com', 'published_date': '2026-06-18T00:00:00+00:00', 'category': None, 'author': 'Kautsar', 'content': 'Ini test insert dari Python', 'image_url': None, 'scraped_at': None}] count=None

# %%
import pandas as pd

df = pd.read_csv(
    "csv/all_news_labeled.csv"
)

print(df.columns.tolist())
# Out:
# ['source', 'title', 'url', 'published_date', 'author', 'category', 'content', 'all_kecamatan', 'primary_kecamatan', 'latitude', 'longitude', 'text', 'sentiment', 'sentiment_score']

# %%
from supabase import create_client
from dotenv import load_dotenv

import pandas as pd
import numpy as np
import os

load_dotenv()

SUPABASE_URL = os.getenv(
    "SUPABASE_URL"
)

SUPABASE_KEY = os.getenv(
    "SUPABASE_KEY"
)

supabase = create_client(
    SUPABASE_URL,
    SUPABASE_KEY
)

df = pd.read_csv(
    "csv/all_news_labeled.csv"
)

# sementara semua sama dulu
df["scraped_at"] = (
    pd.Timestamp.now(tz="UTC")
    .isoformat()
)

# ubah list jadi string
if "all_kecamatan" in df.columns:

    df["all_kecamatan"] = (
        df["all_kecamatan"]
        .astype(str)
    )

# bersihkan NaN
df = df.replace(
    {
        np.nan: None
    }
)

records = df.to_dict(
    "records"
)

batch_size = 500

for i in range(
    0,
    len(records),
    batch_size
):

    batch = records[
        i:i+batch_size
    ]

    supabase.table(
        "news_articles_final"
    ).upsert(
        batch,
        on_conflict="url"
    ).execute()

    print(
        f"uploaded {i + len(batch)} / {len(records)}"
    )

print("DONE")
# Out:
# uploaded 108 / 108
# DONE
